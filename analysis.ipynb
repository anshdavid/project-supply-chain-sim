# %%
from __future__ import annotations

from typing import Any, cast
import pprint

import json

# %%
SIMULATION_DUMP = r"/app/logs/simulation_dump.json"

# %%
simulation_dump = {}    
with open(SIMULATION_DUMP) as f:
    content = f.read()
    simulation_dump = json.loads(content)

# %%
pprint.pprint(simulation_dump)
# Out:
# {'factory_state': {'logs': [],
#                    'meta_data': {'machines': {'M1': {'broken': 3920.39999999753,
#                                                      'idle': 96.09999999999881,
#                                                      'working': 57401.59999944519},
#                                               'M2': {'broken': 3619.5999999978035,
#                                                      'idle': 223.2999999999916,
#                                                      'working': 57575.199999442666}},
#                                  'repairmen': {'R1': {'idle': 57518.0999994435,
#                                                       'working': 3899.9999999975485},
#                                                'R2': {'idle': 57818.09999943913,
#                                                       'working': 3599.9999999978213}}},
#                    'name': 'TestFactory'},
#  'machine_state': [{'fixed_time_to_failure': False,
# ...
