# %%
from __future__ import annotations

from typing import Any, cast
import pprint

import json

# %%
SIMULATION_DUMP = r"/app/logs/simulation_dump.json"

# %%
simulation_dump = {}    
with open(SIMULATION_DUMP) as f:
    content = f.read()
    simulation_dump = json.loads(content)
# Out:
# {'factory_state': {'logs': [],
#                    'meta_data': {'machines': {'M1': {'broken': 905.4000000001373,
#                                                      'idle': 223.1999999999916,
#                                                      'working': 12704.400000028687},
#                                               'M2': {'broken': 1206.4999999999982,
#                                                      'idle': 41.200000000000315,
#                                                      'working': 12585.300000028254},
#                                               'M3': {'broken': 301.2,
#                                                      'idle': 469.10000000003816,
#                                                      'working': 13062.70000002999}},
#                                  'repairmen': {'R1': {'idle': 12633.000000028427,
#                                                       'working': 1200.000000000004},
#                                                'R2': {'idle': 12633.000000028427,
#                                                       'working': 1200.000000000004}}},
#                    'name': 'TestFactory'},
#  'machine_state': [{'fixed_time_to_failure': False,
#                     'fixed_time_to_produce': True,
#                     'mean_operation_time': 600.0,
#                     'mttf': 3600.0,
#                     'name': 'M1',
#                     'operation_cost': 100.0,
#                     'parts_pending': 0,
#                     'parts_produced': 20,
#                     'sigma_operation_time': 1.0,
#                     'state': 'idle'},
#                    {'fixed_time_to_failure': False,
#                     'fixed_time_to_produce': True,
#                     'mean_operation_time': 300.0,
#                     'mttf': 3600.0,
#                     'name': 'M2',
#                     'operation_cost': 200.0,
#                     'parts_pending': 0,
#                     'parts_produced': 40,
#                     'sigma_operation_time': 1.0,
#                     'state': 'idle'},
#                    {'fixed_time_to_failure': False,
#                     'fixed_time_to_produce': True,
#                     'mean_operation_time': 60.0,
#                     'mttf': 3600.0,
#                     'name': 'M3',
#                     'operation_cost': 300.0,
#                     'parts_pending': 0,
#                     'parts_produced': 217,
#                     'sigma_operation_time': 1.0,
#                     'state': 'idle'}],
#  'repairman_state': [{'downtime': 60.0,
#                       'name': 'R1',
#                       'operation_cost': 100.0,
#                       'sigma_time_to_repair': 1.0,
#                       'state': 'idle',
#                       'time_to_repair': 300.0},
#                      {'downtime': 60.0,
#                       'name': 'R2',
#                       'operation_cost': 100.0,
#                       'sigma_time_to_repair': 1.0,
#                       'state': 'idle',
#                       'time_to_repair': 300.0}]}
